# %% [markdown]
# # Week 1 -- Load and Clean Data

# %% [markdown]
# ## Summary
#
# The first assignment is to load and clean the data.  Your data consists of three different files:
#
# ```
# questions.csv
# responses.csv
# ```
#
# These files are straight from the client and were not scrubbed for consistency.  Each file has its own risks of problems.  The questions will guide you through the process of cleaning the data.

# %% [markdown]
# ## Q1 : Inspect & Clean ```questions.csv```
#
# Use pandas to load and inspect the ```question.csv``` data and ensure the questions make sense to you.
#  - how many measurement categories are there?
#  - do you notice anything strange about the category labels?
#  - clean up the measurement categories if necessary
#  - save the clean version of the file under the name: ```questions_clean.csv```

# %% [markdown]
# ## Q2: Inspect & Clean ```reponses.csv```
#
# Use pandas to load and inspect the ```responses.csv``` data and ensure the responses fit the five point Likert scale.
#
# Label | Description
# --|--
# 1 | strongly disagree
# 2 | disagree
# 3 | neutral
# 4 | agree
# 5 | strongly agree
#
# Since this file was generated by the automated software, you do not expect any significant issues, but better be safe than sorry.  Let's double check to make sure.
#
# (a) Are any responses outside the expected range?
#  - If so, what should you do about it?
#
# (b) Do you observe any partial survey completions?
#  - If so, what should you do about it?
#
# (c) Create visualizations of the “answer” column to get a sense of the distribution.  What are your initial thoughts of the employee satisfaction levels?
#
# (d) Let's assume an equal distance between each label so that we can translate individual scores to a percentage. This results in the following scores:
#
# Label | Description | Percent Score
# --|--|--
# 1 | strongly disagree | 0.20
# 2 | disagree | 0.40
# 3 | neutral | 0.60
# 4 | agree | 0.80
# 5 | strongly agree | 1.00
#
# add a column called ```score``` to you dataframe and place the computed score for each answer.
#
# (e) Save a clean version of the file once you have fixed issues.  Use the name: ```responses_clean.csv```
